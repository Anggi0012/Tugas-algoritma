# %%
print( "Jika diketahui bahwa 𝑛 adalah dua digit terakhir dari NIM kalian, maka tentukan biangan prima antara 1000𝑛 dan 1000(𝑛+1)")
print( " Nim = 28 jadi nilai prima yang harus dicari dari 28000 sampai 29000")
print(" jadi nilai prima dari 28000-29000 adalah:")
for n in range(28000, 29001):
    prima_28 = True
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            prima_28 = False
            break
    if prima_28:
        print(n)
# Out:
# Jika diketahui bahwa 𝑛 adalah dua digit terakhir dari NIM kalian, maka tentukan biangan prima antara 1000𝑛 dan 1000(𝑛+1)
#  Nim = 28 jadi nilai prima yang harus dicari dari 28000 sampai 29000
#  jadi nilai prima dari 28000-29000 adalah:
# 28001
# 28019
# 28027
# 28031
# 28051
# 28057
# 28069
# 28081
# 28087
# 28097
# 28099
# 28109
# 28111
# 28123
# 28151
# 28163
# 28181
# 28183
# 28201
# 28211
# 28219
# 28229
# 28277
# 28279
# 28283
# 28289
# 28297
# 28307
# 28309
# 28319
# 28349
# 28351
# 28387
# 28393
# 28403
# 28409
# 28411
# 28429
# 28433
# 28439
# 28447
# 28463
# 28477
# 28493
# 28499
# 28513
# 28517
# 28537
# 28541
# 28547
# 28549
# 28559
# 28571
# 28573
# 28579
# 28591
# 28597
# 28603
# 28607
# 28619
# 28621
# 28627
# 28631
# 28643
# 28649
# 28657
# 28661
# 28663
# 28669
# 28687
# 28697
# 28703
# 28711
# 28723
# 28729
# 28751
# 28753
# 28759
# 28771
# 28789
# 28793
# 28807
# 28813
# 28817
# 28837
# 28843
# 28859
# 28867
# 28871
# 28879
# 28901
# 28909
# 28921
# 28927
# 28933
# ...
